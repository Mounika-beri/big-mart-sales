# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv('/content/bigmart.csv')

# %%
df.head(4)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df1=pd.get_dummies(data=df,drop_first=True)

# %%
df1.corr()
# Out:
#                                Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                       1.000000        -0.014048  0.027141
# Item_Visibility                  -0.014048         1.000000 -0.001315
# Item_MRP                          0.027141        -0.001315  1.000000
# Outlet_Establishment_Year        -0.011588        -0.074834  0.005020
# Item_Outlet_Sales                 0.014123        -0.128625  0.567574
# ...                                    ...              ...       ...
# Outlet_Location_Type_Tier 2      -0.015474        -0.068787  0.001951
# Outlet_Location_Type_Tier 3       0.011818         0.009650 -0.000744
# Outlet_Type_Supermarket Type1    -0.003398        -0.144249  0.004885
# Outlet_Type_Supermarket Type2     0.001315        -0.034671  0.003850
# Outlet_Type_Supermarket Type3          NaN        -0.051144 -0.006714
#
#                                Outlet_Establishment_Year  Item_Outlet_Sales  \
# Item_Weight                                    -0.011588           0.014123
# Item_Visibility                                -0.074834          -0.128625
# Item_MRP                                        0.005020           0.567574
# Outlet_Establishment_Year                       1.000000          -0.049135
# Item_Outlet_Sales                              -0.049135           1.000000
# ...                                                  ...                ...
# Outlet_Location_Type_Tier 2                     0.540820           0.058261
# Outlet_Location_Type_Tier 3                    -0.333895           0.046376
# Outlet_Type_Supermarket Type1                   0.245070           0.108765
# Outlet_Type_Supermarket Type2                   0.466336          -0.038059
# Outlet_Type_Supermarket Type3                  -0.538072           0.311192
#
#                                Item_Identifier_DRA24  Item_Identifier_DRA59  \
# Item_Weight                                 0.037224              -0.028816
# Item_Visibility                            -0.010041               0.040746
# Item_MRP                                    0.010633               0.021750
# Outlet_Establishment_Year                  -0.009699              -0.007165
# Item_Outlet_Sales                           0.001091               0.007780
# ...                                              ...                    ...
# Outlet_Location_Type_Tier 2                -0.002509              -0.013185
# Outlet_Location_Type_Tier 3                 0.002085               0.006711
# Outlet_Type_Supermarket Type1              -0.004999              -0.009948
# Outlet_Type_Supermarket Type2              -0.010022               0.001586
# Outlet_Type_Supermarket Type3               0.003042               0.001500
#
#                                Item_Identifier_DRB01  Item_Identifier_DRB13  \
# Item_Weight                                -0.019823              -0.038659
# Item_Visibility                             0.005817              -0.027297
# Item_MRP                                    0.014643               0.018948
# Outlet_Establishment_Year                  -0.016808               0.003381
# Item_Outlet_Sales                          -0.007294               0.003515
# ...                                              ...                    ...
# Outlet_Location_Type_Tier 2                -0.013073               0.003783
# Outlet_Location_Type_Tier 3                 0.010512               0.000345
# Outlet_Type_Supermarket Type1               0.000486               0.007420
# Outlet_Type_Supermarket Type2              -0.006559              -0.008469
# Outlet_Type_Supermarket Type3               0.013427              -0.008505
#
#                                Item_Identifier_DRB24  ...  \
# Item_Weight                                -0.020884  ...
# Item_Visibility                            -0.019113  ...
# Item_MRP                                    0.004688  ...
# Outlet_Establishment_Year                   0.013378  ...
# Item_Outlet_Sales                           0.011040  ...
# ...                                              ...  ...
# Outlet_Location_Type_Tier 2                 0.019553  ...
# Outlet_Location_Type_Tier 3                -0.017438  ...
# Outlet_Type_Supermarket Type1               0.015749  ...
# Outlet_Type_Supermarket Type2              -0.007574  ...
# Outlet_Type_Supermarket Type3              -0.007606  ...
#
#                                Outlet_Identifier_OUT045  \
# Item_Weight                                   -0.017409
# Item_Visibility                               -0.038353
# Item_MRP                                      -0.000239
# Outlet_Establishment_Year                      0.174150
# Item_Outlet_Sales                              0.002274
# ...                                                 ...
# Outlet_Location_Type_Tier 2                    0.502042
# Outlet_Location_Type_Tier 3                   -0.281465
# Outlet_Type_Supermarket Type1                  0.254208
# Outlet_Type_Supermarket Type2                 -0.122260
# Outlet_Type_Supermarket Type3                 -0.122776
#
#                                Outlet_Identifier_OUT046  \
# Item_Weight                                    0.000768
# Item_Visibility                               -0.038444
# Item_MRP                                       0.005983
# Outlet_Establishment_Year                     -0.034777
# Item_Outlet_Sales                              0.019803
# ...                                                 ...
# Outlet_Location_Type_Tier 2                   -0.243819
# Outlet_Location_Type_Tier 3                   -0.281635
# Outlet_Type_Supermarket Type1                  0.254361
# Outlet_Type_Supermarket Type2                 -0.122333
# Outlet_Type_Supermarket Type3                 -0.122850
#
#                                Outlet_Identifier_OUT049  Outlet_Size_Medium  \
# Item_Weight                                    0.005017            0.004862
# Item_Visibility                               -0.036130           -0.081061
# Item_MRP                                      -0.003906           -0.004510
# Outlet_Establishment_Year                      0.048836           -0.016346
# Item_Outlet_Sales                              0.034264            0.204701
# ...                                                 ...                 ...
# Outlet_Location_Type_Tier 2                   -0.243819           -0.486397
# Outlet_Location_Type_Tier 3                   -0.281635            0.391617
# Outlet_Type_Supermarket Type1                  0.254361           -0.471782
# Outlet_Type_Supermarket Type2                 -0.122333            0.500670
# Outlet_Type_Supermarket Type3                 -0.122850            0.502787
#
#                                Outlet_Size_Small  Outlet_Location_Type_Tier 2  \
# Item_Weight                            -0.001233                    -0.015474
# Item_Visibility                         0.063502                    -0.068787
# Item_MRP                                0.009793                     0.001951
# Outlet_Establishment_Year              -0.056567                     0.540820
# Item_Outlet_Sales                      -0.098403                     0.058261
# ...                                          ...                          ...
# Outlet_Location_Type_Tier 2             0.083381                     1.000000
# Outlet_Location_Type_Tier 3            -0.502066                    -0.560639
# Outlet_Type_Supermarket Type1           0.163388                     0.506347
# Outlet_Type_Supermarket Type2          -0.218082                    -0.243524
# Outlet_Type_Supermarket Type3          -0.219004                    -0.244554
#
#                                Outlet_Location_Type_Tier 3  \
# Item_Weight                                       0.011818
# Item_Visibility                                   0.009650
# Item_MRP                                         -0.000744
# Outlet_Establishment_Year                        -0.333895
# Item_Outlet_Sales                                 0.046376
# ...                                                    ...
# Outlet_Location_Type_Tier 2                      -0.560639
# Outlet_Location_Type_Tier 3                       1.000000
# Outlet_Type_Supermarket Type1                    -0.636465
# Outlet_Type_Supermarket Type2                     0.434369
# Outlet_Type_Supermarket Type3                     0.436205
#
#                                Outlet_Type_Supermarket Type1  \
# Item_Weight                                        -0.003398
# Item_Visibility                                    -0.144249
# Item_MRP                                            0.004885
# Outlet_Establishment_Year                           0.245070
# Item_Outlet_Sales                                   0.108765
# ...                                                      ...
# Outlet_Location_Type_Tier 2                         0.506347
# Outlet_Location_Type_Tier 3                        -0.636465
# Outlet_Type_Supermarket Type1                       1.000000
# Outlet_Type_Supermarket Type2                      -0.480943
# Outlet_Type_Supermarket Type3                      -0.482977
#
#                                Outlet_Type_Supermarket Type2  \
# Item_Weight                                         0.001315
# Item_Visibility                                    -0.034671
# Item_MRP                                            0.003850
# Outlet_Establishment_Year                           0.466336
# Item_Outlet_Sales                                  -0.038059
# ...                                                      ...
# Outlet_Location_Type_Tier 2                        -0.243524
# Outlet_Location_Type_Tier 3                         0.434369
# Outlet_Type_Supermarket Type1                      -0.480943
# Outlet_Type_Supermarket Type2                       1.000000
# Outlet_Type_Supermarket Type3                      -0.122702
#
#                                Outlet_Type_Supermarket Type3
# Item_Weight                                              NaN
# Item_Visibility                                    -0.051144
# Item_MRP                                           -0.006714
# Outlet_Establishment_Year                          -0.538072
# Item_Outlet_Sales                                   0.311192
# ...                                                      ...
# Outlet_Location_Type_Tier 2                        -0.244554
# Outlet_Location_Type_Tier 3                         0.436205
# Outlet_Type_Supermarket Type1                      -0.482977
# Outlet_Type_Supermarket Type2                      -0.122702
# Outlet_Type_Supermarket Type3                       1.000000
#
# [1598 rows x 1598 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# Handle missing values
df['Item_Weight'].fillna(df['Item_Weight'].mean(), inplace=True)
df['Outlet_Size'].fillna(df['Outlet_Size'].mode()[0], inplace=True)

# Identify categorical variables
categorical_columns = df.select_dtypes(include=['object']).columns

# Encode categorical variables
label_encoders = {}
for col in categorical_columns:
    label_encoders[col] = LabelEncoder()
    df[col] = label_encoders[col].fit_transform(df[col])

# Check the preprocessed data
print(df.head())
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              156         9.30                 1         0.016047          4
# 1                8         5.92                 2         0.019278         14
# 2              662        17.50                 1         0.016760         10
# 3             1121        19.20                 2         0.000000          6
# 4             1297         8.93                 1         0.000000          9
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092                  9                       1999            1
# 1   48.2692                  3                       2009            1
# 2  141.6180                  9                       1999            1
# 3  182.0950                  0                       1998            1
# 4   53.8614                  1                       1987            0
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales  \
# 0                     0            1          3735.1380
# 1                     2            2           443.4228
# 2                     0            1          2097.2700
# 3                     2            0           732.3800
# 4                     2            1           994.7052
#
#    Item_Visibility_MeanRatio
# 0                   0.922960
# 1                   1.003057
# 2                   0.831990
# 3                   0.000000
# 4                   0.000000

# %%
df['Item_Visibility_MeanRatio'] = df.apply(lambda x: x['Item_Visibility']/df[df['Item_Identifier']==x['Item_Identifier']]['Item_Visibility'].mean(), axis=1)
print(df.head())
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              156         9.30                 1         0.016047          4
# 1                8         5.92                 2         0.019278         14
# 2              662        17.50                 1         0.016760         10
# 3             1121        19.20                 2         0.000000          6
# 4             1297         8.93                 1         0.000000          9
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092                  9                       1999            1
# 1   48.2692                  3                       2009            1
# 2  141.6180                  9                       1999            1
# 3  182.0950                  0                       1998            1
# 4   53.8614                  1                       1987            0
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales  \
# 0                     0            1          3735.1380
# 1                     2            2           443.4228
# 2                     0            1          2097.2700
# 3                     2            0           732.3800
# 4                     2            1           994.7052
#
#    Item_Visibility_MeanRatio
# 0                   0.922960
# 1                   1.003057
# 2                   0.831990
# 3                   0.000000
# 4                   0.000000

# %%
X = df.drop('Item_Outlet_Sales', axis=1)
y = df['Item_Outlet_Sales']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor

# Create a Random Forest regressor
model = RandomForestRegressor(n_estimators=100, random_state=42)

# Train the model
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
df['Item_Identifier'].unique()
# Out:
# array([ 156,    8,  662, ..., 1323, 1524, 1519])

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Make predictions
y_pred = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error: 1261541.32861209
# R-squared: 0.5496093381549239

# %%
from sklearn.model_selection import GridSearchCV

# Define parameter grid
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Initialize GridSearchCV
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)

# Fit GridSearchCV
grid_search.fit(X_train, y_train)

# Best parameters and score
print(grid_search.best_params_)
print(grid_search.best_score_)
